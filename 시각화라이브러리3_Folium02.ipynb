# %% [markdown]
# # folium

# %%
import numpy as np
import pandas as pd
import folium

# %%
folium.__version__
# Out:
# '0.16.0'

# %% [markdown]
# ## 5. 지도에 마커(marker) 설정

# %% [markdown]
# - POI(Point Of Interest, 관심지점)을 추가하고 관련 정보 제공
# - 마커(marker) : 특정 위치를 표시하는 표식

# %% [markdown]
# ### 마커를 부착한 지도 생성

# %% [markdown]
# 단계1. 마커 생성
# - **folium.Marker(location=[위도,경도], popup='', tooltip='', icon=아이콘객체)**
#    - popup : 마커 클릭 시 표시되는 문구
#        - 환경에 따라 지원 안되는 경우도 있음
#    - tooltip : 마우스 hover시 표기되는 문구
#    - icon : Marker 형태 결정
#        - 기본값 : information icon
#
# 단계2. 마커 아이콘 생성
# - **folium.Icon(color='색상', icon='아이콘 모양')**
#
#
#
# 단계3. 마커 생성 후 부착
# - **folium.Marker().add_to(지도객체변수)**

# %% [markdown]
# #### Map 객체 생성

# %%
map1 = folium.Map(location=[37.56, 127.05], zoom_start=10)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e71c23762e01e61e6151f9164dde9cd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e71c23762e01e61e6151f9164dde9cd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e71c23762e01e61e6151f9164dde9cd8 = L.map(
#                 &quot;map_e71c23762e01e61e6151f9164dde9cd8&quot;,
#                 {
#                     center: [37.56, 127.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab2282427510b3ff5dc256dddb00697a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ab2282427510b3ff5dc256dddb00697a.addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Marker 객체 생성 및 Map에 부착

# %%
# 뚝섬역 :  37.547433727420454, 127.04803964585416
# 과천어린이대공원 : 37.42769504509449, 127.01700374788183
# 카카오 판교오피스 : 37.39598490029507, 127.11053956708399
# 멀티캠퍼스 세종캠 : 37.54817134388939, 127.0733980772467

locs = {'뚝섬역' : (37.547433727420454, 127.04803964585416),
        '과천어린이대공원' : (37.42769504509449, 127.01700374788183),
        '카카오판교' : (37.39598490029507, 127.11053956708399),
        '멀티캠퍼스 세종' : (37.54817134388939, 127.0733980772467)}

# %%
folium.Marker((37.547433727420454, 127.04803964585416),
              popup = 'Subway',
              tooltip = '뚝섬역',
              icon = folium.Icon(icon='cloud')).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e71c23762e01e61e6151f9164dde9cd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e71c23762e01e61e6151f9164dde9cd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e71c23762e01e61e6151f9164dde9cd8 = L.map(
#                 &quot;map_e71c23762e01e61e6151f9164dde9cd8&quot;,
#                 {
#                     center: [37.56, 127.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab2282427510b3ff5dc256dddb00697a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ab2282427510b3ff5dc256dddb00697a.addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             tile_layer_ab2282427510b3ff5dc256dddb00697a.addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             var marker_0d2a3f9608252255552c5e3760b3d849 = L.marker(
#                 [37.547433727420454, 127.04803964585416],
#                 {}
#             ).addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             var icon_23473cd665c729f8f3bf1f50354c3ac3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d2a3f9608252255552c5e3760b3d849.setIcon(icon_23473cd665c729f8f3bf1f50354c3ac3);
#
#
#         var popup_0d9754c475d994d71a253c1a27eb5cab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8226bc310bb01104f81fcf2ca29caa4e = $(`&lt;div id=&quot;html_8226bc310bb01104f81fcf2ca29caa4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Subway&lt;/div&gt;`)[0];
#                 popup_0d9754c475d994d71a253c1a27eb5cab.setContent(html_8226bc310bb01104f81fcf2ca29caa4e);
#
#
#
#         marker_0d2a3f9608252255552c5e3760b3d849.bindPopup(popup_0d9754c475d994d71a253c1a27eb5cab)
#         ;
#
#
#
#
#             marker_0d2a3f9608252255552c5e3760b3d849.bindTooltip(
#                 `&lt;div&gt;
#                      뚝섬역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for name, loc in locs.items():
    folium.Marker(loc,
                  popup = name,
                  tooltip = name,
                  icon = folium.Icon(icon='cloud')).add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e71c23762e01e61e6151f9164dde9cd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e71c23762e01e61e6151f9164dde9cd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e71c23762e01e61e6151f9164dde9cd8 = L.map(
#                 &quot;map_e71c23762e01e61e6151f9164dde9cd8&quot;,
#                 {
#                     center: [37.56, 127.05],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab2282427510b3ff5dc256dddb00697a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ab2282427510b3ff5dc256dddb00697a.addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             tile_layer_ab2282427510b3ff5dc256dddb00697a.addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             var marker_0d2a3f9608252255552c5e3760b3d849 = L.marker(
#                 [37.547433727420454, 127.04803964585416],
#                 {}
#             ).addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             var icon_23473cd665c729f8f3bf1f50354c3ac3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d2a3f9608252255552c5e3760b3d849.setIcon(icon_23473cd665c729f8f3bf1f50354c3ac3);
#
#
#         var popup_0d9754c475d994d71a253c1a27eb5cab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8226bc310bb01104f81fcf2ca29caa4e = $(`&lt;div id=&quot;html_8226bc310bb01104f81fcf2ca29caa4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Subway&lt;/div&gt;`)[0];
#                 popup_0d9754c475d994d71a253c1a27eb5cab.setContent(html_8226bc310bb01104f81fcf2ca29caa4e);
#
#
#
#         marker_0d2a3f9608252255552c5e3760b3d849.bindPopup(popup_0d9754c475d994d71a253c1a27eb5cab)
#         ;
#
#
#
#
#             marker_0d2a3f9608252255552c5e3760b3d849.bindTooltip(
#                 `&lt;div&gt;
#                      뚝섬역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_ab2282427510b3ff5dc256dddb00697a.addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             var marker_d6325cd64df33d9b3ff7aaa07da6be87 = L.marker(
#                 [37.547433727420454, 127.04803964585416],
#                 {}
#             ).addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             var icon_e3c01796ffcd9053396978fa74e75685 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d6325cd64df33d9b3ff7aaa07da6be87.setIcon(icon_e3c01796ffcd9053396978fa74e75685);
#
#
#         var popup_b4cff57586d5680ad308fdc1662cc3ff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dca8b9bfb026188c4b38d0c0b7381c12 = $(`&lt;div id=&quot;html_dca8b9bfb026188c4b38d0c0b7381c12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;뚝섬역&lt;/div&gt;`)[0];
#                 popup_b4cff57586d5680ad308fdc1662cc3ff.setContent(html_dca8b9bfb026188c4b38d0c0b7381c12);
#
#
#
#         marker_d6325cd64df33d9b3ff7aaa07da6be87.bindPopup(popup_b4cff57586d5680ad308fdc1662cc3ff)
#         ;
#
#
#
#
#             marker_d6325cd64df33d9b3ff7aaa07da6be87.bindTooltip(
#                 `&lt;div&gt;
#                      뚝섬역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_efedf408ba445fe3d55d4b5af3d62d2f = L.marker(
#                 [37.42769504509449, 127.01700374788183],
#                 {}
#             ).addTo(map_e71c23762e01e61e6151f9164dde9cd8);
#
#
#             var icon_4755359f1a41785854d3d1c26c4e0814 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_efedf408ba445fe3d55d4b5af3d62d2f.setIcon(icon_4755359f1a41785854d3d1c26c4e0814);
#
#
#         var popup_a37cfb1bfb1c160df9741c841bf23425 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e44e716d701b65764d7624d02067d5c6 = $(`&lt;div id=&quot;html_e44e716d701b65764d7624d02067d5c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;과천어린이대공원&lt;/div&gt;`)[0];

# %% [markdown]
# ### 마커 클릭 시 특정 사이트로 이동하기

# %%
lat, lon = [37.42, 127.02]
zoom_size = 13
map2 = folium.Map(location=[lat, lon], zoom_start=zoom_size)
folium.TileLayer(tiles='Stamen Terrain').add_to(map2)
folium.Marker(location=(37.42769504509449, 127.01700374788183),
              popup = '<a href="https://grandpark.seoul.go.kr/main/ko.do" target=_blank>어린이대공원</a>',
              tooltip = '과천어린이대공원',
              icon = folium.Icon(icon='info-sign')).add_to(map2)

folium.Marker(location=(37.54817134388939, 127.0733980772467),
              popup = '<a href="https://withus.sejong.ac.kr/non/et/prsntStat/view.do?dataSeq=1000151" target=_blank>멀티캠퍼스 세종</a>',
              tooltip = '멀티캠퍼스 세종캠',
              icon = folium.Icon(icon='info-sign')).add_to(map2)

map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_213a5136e205b8216fdcc416c34f3c7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_213a5136e205b8216fdcc416c34f3c7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_213a5136e205b8216fdcc416c34f3c7c = L.map(
#                 &quot;map_213a5136e205b8216fdcc416c34f3c7c&quot;,
#                 {
#                     center: [37.42, 127.02],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_162a4da2d6bd250ae27c88e783ca7c44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_162a4da2d6bd250ae27c88e783ca7c44.addTo(map_213a5136e205b8216fdcc416c34f3c7c);
#
#
#             var tile_layer_ddb17c3916c047e233d3033093675345 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ddb17c3916c047e233d3033093675345.addTo(map_213a5136e205b8216fdcc416c34f3c7c);
#
#
#             var marker_8b8e6f7a1b4b96e0ca2ae1ead9dee558 = L.marker(
#                 [37.42769504509449, 127.01700374788183],
#                 {}
#             ).addTo(map_213a5136e205b8216fdcc416c34f3c7c);
#
#
#             var icon_91a2457e40eb9beadb68627cd8110973 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8b8e6f7a1b4b96e0ca2ae1ead9dee558.setIcon(icon_91a2457e40eb9beadb68627cd8110973);
#
#
#         var popup_315c8185c3837950eb2750f3000c0578 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b29899f56baf42ffd12a3a25caf0449 = $(`&lt;div id=&quot;html_0b29899f56baf42ffd12a3a25caf0449&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://grandpark.seoul.go.kr/main/ko.do&quot; target=_blank&gt;어린이대공원&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_315c8185c3837950eb2750f3000c0578.setContent(html_0b29899f56baf42ffd12a3a25caf0449);
#
#
#
#         marker_8b8e6f7a1b4b96e0ca2ae1ead9dee558.bindPopup(popup_315c8185c3837950eb2750f3000c0578)
#         ;
#
#
#
#
#             marker_8b8e6f7a1b4b96e0ca2ae1ead9dee558.bindTooltip(
#                 `&lt;div&gt;
#                      과천어린이대공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ddda5c536fb3da462a4e61fdf53e590d = L.marker(
#                 [37.54817134388939, 127.0733980772467],
#                 {}
#             ).addTo(map_213a5136e205b8216fdcc416c34f3c7c);
#
#
#             var icon_459c8714f49caff969d4e166f6fc0010 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ddda5c536fb3da462a4e61fdf53e590d.setIcon(icon_459c8714f49caff969d4e166f6fc0010);
#
#
#         var popup_6bd4779a572dea41108a3757fda334b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a93efb7c72300773cf2a26a43bf15dc = $(`&lt;div id=&quot;html_4a93efb7c72300773cf2a26a43bf15dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://withus.sejong.ac.kr/non/et/prsntStat/view.do?dataSeq=1000151&quot; target=_blank&gt;멀티캠퍼스 세종&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_6bd4779a572dea41108a3757fda334b8.setContent(html_4a93efb7c72300773cf2a26a43bf15dc);
#
#
#
#         marker_ddda5c536fb3da462a4e61fdf53e590d.bindPopup(popup_6bd4779a572dea41108a3757fda334b8)
#         ;
#
#
#
#
#             marker_ddda5c536fb3da462a4e61fdf53e590d.bindTooltip(
#                 `&lt;div&gt;
#                      멀티캠퍼스 세종캠
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:

# %% [markdown]
# ### 마커에 custom icon 적용하기

# %% [markdown]
# - icon옵션 custom
#     - prefix 옵션 : 두 가지 - fa, glyphicon
#     - prefix='fa' 옵션을 선택할 때 icon 선택하는 사이트
#         - https://fontawesome.com/
#     - prefix = 'glyphicon' 옵션을 선택할 때 icon 선택하는 사이트
#         - http://bootstrapk.com/components/

# %%
lat, lon = [37.42, 127.02]
zoom_size = 9

# 지도 객체 생성
map3 = folium.Map(location=[lat, lon], zoom_start=zoom_size)

# 지도 타일 지정
folium.TileLayer(tiles='Stamen Terrain').add_to(map3)

# Marker를 지정하기 위한 Icon 객체 생성
icon = folium.Icon(color='black', icon='info-sign')

# Marker 객체 생성 후 Map 객체에 추가
folium.Marker(location=(37.42769504509449, 127.01700374788183),
              popup = '<a href="https://grandpark.seoul.go.kr/main/ko.do" target=_blank>어린이대공원</a>',
              tooltip = '과천어린이대공원',
              icon = icon).add_to(map3)

# prefix = 'fa'
icon = folium.Icon(color='green', icon='building', prefix='fa')
folium.Marker(location=(37.54817134388939, 127.0733980772467),
              popup = '<a href="https://withus.sejong.ac.kr/non/et/prsntStat/view.do?dataSeq=1000151" target=_blank>멀티캠퍼스 세종</a>',
              tooltip = '멀티캠퍼스 세종캠',
              icon = icon).add_to(map3)

icon = folium.Icon(color='purple', icon='info-sign')
folium.Marker(location=(37.39598490029507, 127.11053956708399),
              popup = '<a href="https://www.kakaocorp.com/page/" target=_blank>카카오</a>',
              tooltip = 'KaKao',
              icon = icon).add_to(map3)

map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5af2b6ded43e5a441e9e7ab9960c9cfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5af2b6ded43e5a441e9e7ab9960c9cfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5af2b6ded43e5a441e9e7ab9960c9cfc = L.map(
#                 &quot;map_5af2b6ded43e5a441e9e7ab9960c9cfc&quot;,
#                 {
#                     center: [37.42, 127.02],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f5d261c2f15d71a544a75bdcee7566f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0f5d261c2f15d71a544a75bdcee7566f.addTo(map_5af2b6ded43e5a441e9e7ab9960c9cfc);
#
#
#             var tile_layer_581211620e7815710719d59859350978 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_581211620e7815710719d59859350978.addTo(map_5af2b6ded43e5a441e9e7ab9960c9cfc);
#
#
#             var marker_803924a4939d5c6016381aea5642b37d = L.marker(
#                 [37.42769504509449, 127.01700374788183],
#                 {}
#             ).addTo(map_5af2b6ded43e5a441e9e7ab9960c9cfc);
#
#
#             var icon_ec867474080dd17234d36d135a51b0d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_803924a4939d5c6016381aea5642b37d.setIcon(icon_ec867474080dd17234d36d135a51b0d4);
#
#
#         var popup_004a8375d894e3a43fac7fe1a6a93f59 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e7486167168650966b77a9a0d201698 = $(`&lt;div id=&quot;html_5e7486167168650966b77a9a0d201698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://grandpark.seoul.go.kr/main/ko.do&quot; target=_blank&gt;어린이대공원&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_004a8375d894e3a43fac7fe1a6a93f59.setContent(html_5e7486167168650966b77a9a0d201698);
#
#
#
#         marker_803924a4939d5c6016381aea5642b37d.bindPopup(popup_004a8375d894e3a43fac7fe1a6a93f59)
#         ;
#
#
#
#
#             marker_803924a4939d5c6016381aea5642b37d.bindTooltip(
#                 `&lt;div&gt;
#                      과천어린이대공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_19234148b138b8e415528318ed899b76 = L.marker(
#                 [37.54817134388939, 127.0733980772467],
#                 {}
#             ).addTo(map_5af2b6ded43e5a441e9e7ab9960c9cfc);
#
#
#             var icon_3e010aa56a1bab9bd0a23794d95faa79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_19234148b138b8e415528318ed899b76.setIcon(icon_3e010aa56a1bab9bd0a23794d95faa79);
#
#
#         var popup_c1f9724d421dd0fbc68cbbb7f836525a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d88a8c8df94126089fb9853100123da1 = $(`&lt;div id=&quot;html_d88a8c8df94126089fb9853100123da1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://withus.sejong.ac.kr/non/et/prsntStat/view.do?dataSeq=1000151&quot; target=_blank&gt;멀티캠퍼스 세종&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_c1f9724d421dd0fbc68cbbb7f836525a.setContent(html_d88a8c8df94126089fb9853100123da1);
#
#
#
#         marker_19234148b138b8e415528318ed899b76.bindPopup(popup_c1f9724d421dd0fbc68cbbb7f836525a)
#         ;
#
#
#
#
#             marker_19234148b138b8e415528318ed899b76.bindTooltip(
#                 `&lt;div&gt;
#                      멀티캠퍼스 세종캠
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c75fe720a95d8739f3f740816381c690 = L.mark

# %% [markdown]
# ### 문제
#
# 1. 수원역에 있는 에이케이플라자를 지도에 표시
#
#
# 2. icon은 검정색, 건물모양으로 표시
#   - color = 'black'
#   - icon = 'building'
#   - prefix = 'fa'
#
#
# 3. 아이콘에 마우스를 올리면 AK플라자 글씨를 나타나게 함
#
#
# 4. 아이콘 클릭 시 AK플라자 사이트로 연결
#     - http://www.akplaza.com/main.do

# %%
lat, lon = [37.2, 127.02]
zoom_size = 9

map4 = folium.Map(location=[lat, lon], zoom_start=zoom_size)

folium.TileLayer(tiles='Stamen Terrain').add_to(map4)

icon = folium.Icon(color='black', icon='building', prefix='fa')
folium.Marker(location=(37.54817134388939, 127.0733980772467),
              popup = '<a href="http://www.akplaza.com/main.do" target=_blank>AK플라자</a>',
              tooltip = '수원역 AK플라자',
              icon = icon).add_to(map4)

map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0060a9ebab0365531fb4ecb66723bc28 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0060a9ebab0365531fb4ecb66723bc28&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0060a9ebab0365531fb4ecb66723bc28 = L.map(
#                 &quot;map_0060a9ebab0365531fb4ecb66723bc28&quot;,
#                 {
#                     center: [37.2, 127.02],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66b148070d73378cab48ce41d542e1d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_66b148070d73378cab48ce41d542e1d0.addTo(map_0060a9ebab0365531fb4ecb66723bc28);
#
#
#             var tile_layer_e7fe25e2e9ad2105119c43f273361665 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e \u0026mdash; Map data \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7fe25e2e9ad2105119c43f273361665.addTo(map_0060a9ebab0365531fb4ecb66723bc28);
#
#
#             var marker_97cbb8332e23c362bae534927804c76a = L.marker(
#                 [37.54817134388939, 127.0733980772467],
#                 {}
#             ).addTo(map_0060a9ebab0365531fb4ecb66723bc28);
#
#
#             var icon_4298b1732ed069c587dccbb1e4cc8efa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_97cbb8332e23c362bae534927804c76a.setIcon(icon_4298b1732ed069c587dccbb1e4cc8efa);
#
#
#         var popup_e0bfeb70193fcb6ef4d65c7872ae7961 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9eb79d0f3ca66cf019b2ad8c106d66f = $(`&lt;div id=&quot;html_e9eb79d0f3ca66cf019b2ad8c106d66f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;http://www.akplaza.com/main.do&quot; target=_blank&gt;AK플라자&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_e0bfeb70193fcb6ef4d65c7872ae7961.setContent(html_e9eb79d0f3ca66cf019b2ad8c106d66f);
#
#
#
#         marker_97cbb8332e23c362bae534927804c76a.bindPopup(popup_e0bfeb70193fcb6ef4d65c7872ae7961)
#         ;
#
#
#
#
#             marker_97cbb8332e23c362bae534927804c76a.bindTooltip(
#                 `&lt;div&gt;
#                      수원역 AK플라자
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 문제2.
# 1) 서울시 공중화장실 위치를 찾아 종로구 옥인동에 있는 공중화장실에 Marker 생성하여 지도시각화하기

# %% [markdown]
# ## 6. 지도에 원 그리기

# %% [markdown]
# : 지도에 데이터 값, 영역 등의 정보를 표현하기 위한 방법
#
# - folium.Circle()
# - folium.CircleMarker()

# %% [markdown]
# #### Circle()  생성

# %%
lat, lon = 37.54, 127.05469
zoom_size = 15
m = folium.Map(location=[lat, lon], zoom_start=zoom_size)

# %%
# circle
folium.Circle(location=[lat,lon],
              radius=100,
              color='red',
              fill_color='blue',
              popup='Circle popup',
              tooltip='Circle tooltip').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_418474eab01951aefa250eb90d2c5074 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_418474eab01951aefa250eb90d2c5074&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_418474eab01951aefa250eb90d2c5074 = L.map(
#                 &quot;map_418474eab01951aefa250eb90d2c5074&quot;,
#                 {
#                     center: [37.54, 127.05469],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_891bdc35ec9f74af7c8cfe806297f8d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_891bdc35ec9f74af7c8cfe806297f8d1.addTo(map_418474eab01951aefa250eb90d2c5074);
#
#
#             tile_layer_891bdc35ec9f74af7c8cfe806297f8d1.addTo(map_418474eab01951aefa250eb90d2c5074);
#
#
#             var circle_855efb7f8cd5d10af4218781d4ffb220 = L.circle(
#                 [37.54, 127.05469],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_418474eab01951aefa250eb90d2c5074);
#
#
#         var popup_5346b23e0536c40c23bf52952d357542 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfe9aad2c46790aa4309ec353910792d = $(`&lt;div id=&quot;html_dfe9aad2c46790aa4309ec353910792d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle popup&lt;/div&gt;`)[0];
#                 popup_5346b23e0536c40c23bf52952d357542.setContent(html_dfe9aad2c46790aa4309ec353910792d);
#
#
#
#         circle_855efb7f8cd5d10af4218781d4ffb220.bindPopup(popup_5346b23e0536c40c23bf52952d357542)
#         ;
#
#
#
#
#             circle_855efb7f8cd5d10af4218781d4ffb220.bindTooltip(
#                 `&lt;div&gt;
#                      Corcle tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_891bdc35ec9f74af7c8cfe806297f8d1.addTo(map_418474eab01951aefa250eb90d2c5074);
#
#
#             var circle_855d5911258ff97cf14d5e139fa1d96e = L.circle(
#                 [37.54, 127.05469],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_418474eab01951aefa250eb90d2c5074);
#
#
#         var popup_7ec597b6338e7b46ebb5b62a0c560e19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01d067dcc07d7ea9baf6cb333746caee = $(`&lt;div id=&quot;html_01d067dcc07d7ea9baf6cb333746caee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle popup&lt;/div&gt;`)[0];
#                 popup_7ec597b6338e7b46ebb5b62a0c560e19.setContent(html_01d067dcc07d7ea9baf6cb333746caee);
#
#
#
#         circle_855d5911258ff97cf14d5e139fa1d96e.bindPopup(popup_7ec597b6338e7b46ebb5b62a0c560e19)
#         ;
#
#
#
#
#             circle_855d5911258ff97cf14d5e139fa1d96e.bindTooltip(
#                 `&lt;div&gt;
#                      Circle tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### CircleMarker 생성

# %%
lat, lon = 37.54, 127.05469
zoom_size = 15
m = folium.Map(location=[lat, lon], zoom_start=zoom_size)

folium.CircleMarker(location=[lat,lon],
                    radius=50,
                    color='#34ebc6',
                    fill_color='#c634eb',
                    popup='CircleMarker popup',
                    tooltip='CircleMarker tooltip').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e59674261e6636f4b6ff8be24c1cb57f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e59674261e6636f4b6ff8be24c1cb57f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e59674261e6636f4b6ff8be24c1cb57f = L.map(
#                 &quot;map_e59674261e6636f4b6ff8be24c1cb57f&quot;,
#                 {
#                     center: [37.54, 127.05469],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_761abb5a14cc7521e9e8a835f17cd885 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_761abb5a14cc7521e9e8a835f17cd885.addTo(map_e59674261e6636f4b6ff8be24c1cb57f);
#
#
#             var circle_marker_62d321f4df6aa7efba96e257f5bb1d6b = L.circleMarker(
#                 [37.54, 127.05469],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#34ebc6&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c634eb&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e59674261e6636f4b6ff8be24c1cb57f);
#
#
#         var popup_e29d24de49c6622140cd641fe96f2bf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c2da5c1a0f2814bfbdd6a72b334c3dd = $(`&lt;div id=&quot;html_4c2da5c1a0f2814bfbdd6a72b334c3dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CircleMarker popup&lt;/div&gt;`)[0];
#                 popup_e29d24de49c6622140cd641fe96f2bf1.setContent(html_4c2da5c1a0f2814bfbdd6a72b334c3dd);
#
#
#
#         circle_marker_62d321f4df6aa7efba96e257f5bb1d6b.bindPopup(popup_e29d24de49c6622140cd641fe96f2bf1)
#         ;
#
#
#
#
#             circle_marker_62d321f4df6aa7efba96e257f5bb1d6b.bindTooltip(
#                 `&lt;div&gt;
#                      CircleMarker tooltip
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 7. MarkerCluster 생성
#
# - 가까운 거리의 Marker들을 그룹화하여 Marker의 개수로 표현
# - folium.plugin의 MarkerCluster클래스
# - https://python-visualization.github.io/folium/latest/user_guide/plugins/marker_cluster.html#MarkerCluster

# %% [markdown]
# ### MarkerCluster 추가 방법
#
# 1. Map 객체 생성
# 2. MarkerCluster 객체 생성하여 Map에 추가
# 3. MarkerCluster 객체에 Marker 추가

# %%
# 서울시 구청 위치 정보
gu_loc = {'강남구청':[37.52579, 127.0483],
        '서초구청':[37.49093, 127.0329],
        '동작구청':[37.51871, 126.9364],
        '구로구청':[37.50237, 126.8890],
        '양천구청' :[37.52007, 126.9549],
        '영등포구청': [37.54240, 126.8402],
        '관악구청': [37.48467, 126.9515],
        '용산구청' :[37.53804, 126.9913],
        '서대문구청': [37.58567, 126.9357],
        '마포구청' : [37.57003, 126.9019],
        '은평구청' : [37.60675, 126.9302],
        '종로구청' : [37.57615, 126.9790],
        '중구청' : [37.56798, 126.9975],
        '성북구청' : [37.59342, 127.0172],
        '동대문구청' : [37.57792, 127.0401],
        '중랑구청' : [37.60961, 127.0931],
        '노원구청' : [37.65664, 127.0559],
        '도봉구청' : [37.67214, 127.0462],
        '강북구청' : [37.64278, 127.0253],
        '광진구청' : [37.54104, 127.0826],
        '강동구청' : [37.53246, 127.1237],
        '송파구청' : [37.51803, 127.105]
       }

# %% [markdown]
# - map 객체 생성

# %%
lat, lon = 37.56668940479636, 126.97863915872446
zoom_size = 12
tiles = 'https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png'
attr = 'Stadia Maps'
m = folium.Map(location=[lat, lon], zoom_start=zoom_size)
folium.TileLayer(tiles=tiles, attr=attr).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c799276a80f76efde75cfeef13090ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c799276a80f76efde75cfeef13090ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c799276a80f76efde75cfeef13090ea = L.map(
#                 &quot;map_1c799276a80f76efde75cfeef13090ea&quot;,
#                 {
#                     center: [37.56668940479636, 126.97863915872446],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57bb37c22a877185830bf409fed23bc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_57bb37c22a877185830bf409fed23bc5.addTo(map_1c799276a80f76efde75cfeef13090ea);
#
#
#             var tile_layer_67bb861da168116134fed8f3746f5e4d = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Stadia Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_67bb861da168116134fed8f3746f5e4d.addTo(map_1c799276a80f76efde75cfeef13090ea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 각 구의 구청 위치에 Marker로 표시

# %%
colors = ['blue']*6+['yellow']*5+['red']*5+['green']*6
iconShape = ['cloud', 'info-sign', 'building']*7+['cloud']
prefix = 'fa'
icon = folium.Icon(color = colors, icon= iconShape, prefix=prefix)
folium.Marker(location=loc, icon=icon, tooltip=, popup=).add_to(m)

# %%
for name, loc in gu_loc.items():
    folium.Marker(loc,
                  popup = name,
                  tooltip = name,
                  icon = folium.Icon(icon='cloud')).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70575b84ab59fff27165b8b4591c92db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70575b84ab59fff27165b8b4591c92db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70575b84ab59fff27165b8b4591c92db = L.map(
#                 &quot;map_70575b84ab59fff27165b8b4591c92db&quot;,
#                 {
#                     center: [37.56668940479636, 126.97863915872446],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01b678fe49e959bcd17da8c691a72df0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_01b678fe49e959bcd17da8c691a72df0.addTo(map_70575b84ab59fff27165b8b4591c92db);
#
#
#             var tile_layer_d2d9c346c9b242fc7200651744b7c236 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Stadia Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d2d9c346c9b242fc7200651744b7c236.addTo(map_70575b84ab59fff27165b8b4591c92db);
#
#
#             tile_layer_01b678fe49e959bcd17da8c691a72df0.addTo(map_70575b84ab59fff27165b8b4591c92db);
#
#
#             tile_layer_d2d9c346c9b242fc7200651744b7c236.addTo(map_70575b84ab59fff27165b8b4591c92db);
#
#
#             var marker_219fcfca4563fdf8f2bcb9e7614b4170 = L.marker(
#                 [37.52579, 127.0483],
#                 {}
#             ).addTo(map_70575b84ab59fff27165b8b4591c92db);
#
#
#             var icon_92068643da352c158fc4d536724cec64 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_219fcfca4563fdf8f2bcb9e7614b4170.setIcon(icon_92068643da352c158fc4d536724cec64);
#
#
#         var popup_108514121df026b72e3cf0e283f64338 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_664600d389b4823a70bb5fffdcf8ebf7 = $(`&lt;div id=&quot;html_664600d389b4823a70bb5fffdcf8ebf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구청&lt;/div&gt;`)[0];
#                 popup_108514121df026b72e3cf0e283f64338.setContent(html_664600d389b4823a70bb5fffdcf8ebf7);
#
#
#
#         marker_219fcfca4563fdf8f2bcb9e7614b4170.bindPopup(popup_108514121df026b72e3cf0e283f64338)
#         ;
#
#
#
#
#             marker_219fcfca4563fdf8f2bcb9e7614b4170.bindTooltip(
#                 `&lt;div&gt;
#                      강남구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d90b723040d25d951d17e0163628cbe6 = L.marker(
#                 [37.49093, 127.0329],
#                 {}
#             ).addTo(map_70575b84ab59fff27165b8b4591c92db);
#
#
#             var icon_ff34b51529d5eae7f90853fb1af0899f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d90b723040d25d951d17e0163628cbe6.setIcon(icon_ff34b51529d5eae7f90853fb1af0899f);
#
#
#         var popup_fd5982767ed5cfb2c38d352850898e75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a8bc29deb54649f71810db860620710 = $(`&lt;div id=&quot;html_3a8bc29deb54649f71810db860620710&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구청&lt;/div&gt;`)[0];
#                 popup_fd5982767ed5cfb2c38d352850898e75.setContent(html_3a8bc29deb54649f71810db860620710);
#
#
#
#         marker_d90b723040d25d951d17e0163628cbe6.bindPopup(popup_fd5982767ed5cfb2c38d352850898e75)
#         ;
#
#
#
#
#             marker_d90b723040d25d951d17e0163628cbe6.bindTooltip(
#                 `&lt;div&gt;
#                      서초구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_da9db8f7af6f664630301493f7c6347c = L.marker(
#                 [37.51871, 126.9364],
#                 {}
#             ).addTo(map_70575b84ab59fff27165b8b4591c92db);
#
#
#             var icon_e57d79491e9d0cb9d3dd8c0fd2b20afa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;:

# %% [markdown]
# - MarkerCluster 추가

# %%
from folium.plugins import MarkerCluster

# %%
# MarkerCluster 객체 생성하여 지도에 붙이기
marker_cluster = MarkerCluster().add_to(m)

# Marker를 MarkerCluster에 붙이기
for name, loc in gu_loc.items():
    folium.Marker(loc,
                  popup = name,
                  tooltip = name,
                  icon = folium.Icon(icon='cloud')).add_to(marker_cluster)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c799276a80f76efde75cfeef13090ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c799276a80f76efde75cfeef13090ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c799276a80f76efde75cfeef13090ea = L.map(
#                 &quot;map_1c799276a80f76efde75cfeef13090ea&quot;,
#                 {
#                     center: [37.56668940479636, 126.97863915872446],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57bb37c22a877185830bf409fed23bc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_57bb37c22a877185830bf409fed23bc5.addTo(map_1c799276a80f76efde75cfeef13090ea);
#
#
#             var tile_layer_67bb861da168116134fed8f3746f5e4d = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Stadia Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_67bb861da168116134fed8f3746f5e4d.addTo(map_1c799276a80f76efde75cfeef13090ea);
#
#
#             tile_layer_57bb37c22a877185830bf409fed23bc5.addTo(map_1c799276a80f76efde75cfeef13090ea);
#
#
#             tile_layer_67bb861da168116134fed8f3746f5e4d.addTo(map_1c799276a80f76efde75cfeef13090ea);
#
#
#             var marker_cluster_4aa01bcc44b6ba12a9115d0cd655b911 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_042000d71d089759b2cdc74da7a7cea7 = L.marker(
#                 [37.52579, 127.0483],
#                 {}
#             ).addTo(marker_cluster_4aa01bcc44b6ba12a9115d0cd655b911);
#
#
#             var icon_35dd77196e029284cbd39fa56d771613 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_042000d71d089759b2cdc74da7a7cea7.setIcon(icon_35dd77196e029284cbd39fa56d771613);
#
#
#         var popup_f2d0913ddacd304dcc54bd603afef834 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c26cf2845c3669013f0eeaeacc469ef2 = $(`&lt;div id=&quot;html_c26cf2845c3669013f0eeaeacc469ef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구청&lt;/div&gt;`)[0];
#                 popup_f2d0913ddacd304dcc54bd603afef834.setContent(html_c26cf2845c3669013f0eeaeacc469ef2);
#
#
#
#         marker_042000d71d089759b2cdc74da7a7cea7.bindPopup(popup_f2d0913ddacd304dcc54bd603afef834)
#         ;
#
#
#
#
#             marker_042000d71d089759b2cdc74da7a7cea7.bindTooltip(
#                 `&lt;div&gt;
#                      강남구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_466fe22988312a7dfc969c00a1c1b79e = L.marker(
#                 [37.49093, 127.0329],
#                 {}
#             ).addTo(marker_cluster_4aa01bcc44b6ba12a9115d0cd655b911);
#
#
#             var icon_df1f45f6f23d5c7c1914d46a977efcd0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_466fe22988312a7dfc969c00a1c1b79e.setIcon(icon_df1f45f6f23d5c7c1914d46a977efcd0);
#
#
#         var popup_537c1b80898a6dba7e230d6f3cafbb69 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_098fa40cadf803a49b15c36b22afb8fb = $(`&lt;div id=&quot;html_098fa40cadf803a49b15c36b22afb8fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구청&lt;/div&gt;`)[0];
#                 popup_537c1b80898a6dba7e230d6f3cafbb69.setContent(html_098fa40cadf803a49b15c36b22afb8fb);
#
#
#
#         marker_466fe22988312a7dfc969c00a1c1b79e.bindPopup(popup_537c1b80898a6dba7e230d6f3cafbb69)
#         ;
#
#
#
#
#             marker_466fe22

# %%
m2 = folium.Map(location=[lat, lon], zoom_start=zoom_size)
folium.TileLayer(tiles=tiles, attr=attr).add_to(m2)

marker_cluster = MarkerCluster().add_to(m2)

# Marker를 MarkerCluster에 붙이기
for name, loc in gu_loc.items():
    folium.Marker(loc,
                  popup = folium.Popup(name, max_width=200),
                  tooltip = name,
                  icon = folium.Icon(icon='cloud')).add_to(marker_cluster)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efb27a5eb286f1911abcffc8bba361af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efb27a5eb286f1911abcffc8bba361af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efb27a5eb286f1911abcffc8bba361af = L.map(
#                 &quot;map_efb27a5eb286f1911abcffc8bba361af&quot;,
#                 {
#                     center: [37.56668940479636, 126.97863915872446],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3afa8652162c359961dd167e01e3df59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3afa8652162c359961dd167e01e3df59.addTo(map_efb27a5eb286f1911abcffc8bba361af);
#
#
#             var tile_layer_c2ff2b0fe8e594e4d9bf4202c0313039 = L.tileLayer(
#                 &quot;https://tiles.stadiamaps.com/tiles/osm_bright/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Stadia Maps&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2ff2b0fe8e594e4d9bf4202c0313039.addTo(map_efb27a5eb286f1911abcffc8bba361af);
#
#
#             var marker_cluster_c7be10701cc723968be378b552821a3a = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_102607cc8424512aa8557d34d7eb4182 = L.marker(
#                 [37.52579, 127.0483],
#                 {}
#             ).addTo(marker_cluster_c7be10701cc723968be378b552821a3a);
#
#
#             var icon_0a497860fcdaf97b11e2ed1614f1f27e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_102607cc8424512aa8557d34d7eb4182.setIcon(icon_0a497860fcdaf97b11e2ed1614f1f27e);
#
#
#         var popup_eb6ea094e26b22e7c8effacaa1c070c3 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_bee07af9889fd2e7663efff666da2b1a = $(`&lt;div id=&quot;html_bee07af9889fd2e7663efff666da2b1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남구청&lt;/div&gt;`)[0];
#                 popup_eb6ea094e26b22e7c8effacaa1c070c3.setContent(html_bee07af9889fd2e7663efff666da2b1a);
#
#
#
#         marker_102607cc8424512aa8557d34d7eb4182.bindPopup(popup_eb6ea094e26b22e7c8effacaa1c070c3)
#         ;
#
#
#
#
#             marker_102607cc8424512aa8557d34d7eb4182.bindTooltip(
#                 `&lt;div&gt;
#                      강남구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_402fc3dc3f922df3d015df05ff85429c = L.marker(
#                 [37.49093, 127.0329],
#                 {}
#             ).addTo(marker_cluster_c7be10701cc723968be378b552821a3a);
#
#
#             var icon_2f7c417e21204f3f773950c7e2b40d40 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_402fc3dc3f922df3d015df05ff85429c.setIcon(icon_2f7c417e21204f3f773950c7e2b40d40);
#
#
#         var popup_d03a9d51ac388cf7cfd9e5b14f47e0d5 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_dffab9f92df0378197d23f21234aa488 = $(`&lt;div id=&quot;html_dffab9f92df0378197d23f21234aa488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서초구청&lt;/div&gt;`)[0];
#                 popup_d03a9d51ac388cf7cfd9e5b14f47e0d5.setContent(html_dffab9f92df0378197d23f21234aa488);
#
#
#
#         marker_402fc3dc3f922df3d015df05ff85429c.bindPopup(popup_d03a9d51ac388cf7cfd9e5b14f47e0d5)
#         ;
#
#
#
#
#             marker_402fc3dc3f922df3d015df05ff85429c.bindTooltip(
#                 `&lt;div&gt;
#                      서초구청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3f5626405bec8894a9dc4596214c2237 =

# %% [markdown]
# -----

# %% [markdown]
# ### 연습문제. 서울시 지진대피소 위치를 MarkerCluster 표시하기

# %% [markdown]
# - 데이터 : 서울시 지진옥외대피소
# - 대피소별 주소, 면적, 표값 제공(좌표계: 위경도(GPS), XY좌표(GRS90-중부원점))
# - 출처 : 서울시 열린데이터 광장
# - https://data.seoul.go.kr/dataList/OA-21063/S/1/datasetView.do

# %% [markdown]
# ------
